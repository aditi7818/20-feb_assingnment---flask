# %%
Question 1: Explain GET and POST methods.
Answer: 
GET method: 
The GET method is used to sumbit the HTML form data. This data is collected by predefined $_GET variable for procesing.
The information sent from an HTML from using the GET method is visible to eveyone in the brower's adress bar, 
which means that all the variable names and their values will be displayed in the URL. Therefore, the get method is not secured to send sensitive information.
# NOTE : Only a limited amount of information can be send using the GET method.

Advantages of  GET method(method = "get")

~ You can bookmark the page with the specific query string because the data sent by the GET method is displayed in URL.
~ GET requests can be cached.
~ GET requests are always remained in the browser history.

Disadvntages of GET Method
~ The GET method should not be used while sending any sensitive information.
~ A limited amount of data can be sent using method = "get". This limit should not exceed 2048 characters.
~ For security reasons, never use the GET method to send highly sensitive information like username , password, because it shows them in URL.
~ The GET method cannot be used to send binary data(such as images or word documents) to the server.


POST Method:
Similar to the GET method, the POST method is used to sumbit the HTML form data. But the data submitted by this method is collected by predefined superglobal variable $_POST instead
of $_GET.
Unlike the GET method, it does not have a limit on the amount of information to be sent, The information sent from an HTML from using the POST method is not visible to anyone.

ADVANTAGES of POST method(method = "post")

~ The POST method is useful for sending any sensitive information because the information sent using method is not visible to anyone.
~ There is no limitation on size of data to be sent using the POST Method. You can send a large amount of information using this method.
~ Binary and ASCII data can also be sent using the POST method.
~ Data security depends on the HTTP protocol because the information sent using the POST method goes through the HTTP header. By using secure HTTP, you can ensure that your data is
safe.

DISAVANTAGE of POST Method

~ POST requests do not cache.
~ POST requests never remain in the browser history.
~ It is not possible to bookmark the page because the variables are not displ

# %%
Question 2: Why request used in Flask?
Answer: 
Python Flask -Request Object
In a Flask, we have our own page(client) and a server. The Server should process the data. The Request, in Flask, is an object that contains all the data sent from the client to 
server. This data can be recovered the GET/POST Methods . Post is used when your appliction expects user input to be recived by command or an HTTP request, while GET gets all
the information before it even has a chance for submission. Using both methods at once gives perfect freedom but still requries complex UI patterns like AJAS call etc, with most 
common applications being frameworks where multiple forms are necessary such as Slack webhook, MaligunMailserver, and eCommerce Commerce Framework. with Flask-Request class instead,
we do not have anymore since this API allows us flexible handling of many other situations.

There are various attributes associated with the request objects:
    
SN                               Attribute                                               Description

1.                               Form                                                   It is the dictionary object which contains the key-value pair of form parameters and
                                                                                        thier values.
    
2.                               args                                                    It is parsed from the URL. it is the part of the URL which is specified in the URL 
                                                                                         after question mark(?)

3.                              cookies                                                It is the dictionary object containing cookie names and the values. it is saves at the client
                                                                                        side to track the user session.
    
4.                              method                                                 It is the current request method (get or post).

# %%
Question 3: Why is redirect() used in flask?
Answer: 
A redirect is used in Flask class to send the user to a particular URL with the status code. conversely, this status code additionally identifies the issue. when we access a website,
our browser send a request to the server, and the server replies with what is known as the HTTP status code, which is a three-digit number. the different reason for errors are:
~ Unauthorized access or poor request.
~ Unsupported media file types.
~ Overload of the backend servver.
~ Internal hardware/connection error.

There different type of HTTP codes are:

300                Multiple_choices
301                Moved_permanetly
302                Found
303                See_other
304                Not_modified
305                Use_proxy
306                Reserved
307                Temporary_redirect

Import the redirect attribute

we can redirect the URL using Flask by importing redirect. Let's see how to import redirects from Flask

from flask import redirect

# %%
Question 4: What are templates in Flask? Why is the render_template() function used?
Answer: 
Templates are file that contains static data sa well as placeholders for dynamic data. A template is rendered with specific data to produce a final document.
Flask uses the jinja template liberary to render templates.
In your application, you will use templates to render HTML which will display in the user's browser.

flask.templating render_template :
    render_template is a Flask function from the flask.templating packages. 
render_template is used to generate output from a template file based on the Jinja2 engine that is found in the application's templates folder.

# NOTE: render_template is typically imported directly from the flask package instead of from flask.templating.
